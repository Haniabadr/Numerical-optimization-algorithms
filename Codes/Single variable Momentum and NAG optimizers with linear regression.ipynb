# %% [markdown]
# ### Generate random data

# %% [markdown]
# #### Import numpy, matplotlib.pyplot and make it inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# To have a dataset or set of data points, the student must generate a pair of arrays <b>X</b> and <b>y</b> with the values in <b>X</b> equally distributed between <b>0</b> and <b>20</b> and the values in <b>y</b> such that:
# <b>yi = a*xi + b (and a = -1, b = 2)</b>

# %%
theta_0=0
theta_1=0
alpha=0.01
m=50
a=-1
b=2
X=np.linspace(0,20)
X=X.reshape(50,1)
Y=a*X+b
len(Y)
# Out:
# 50

# %% [markdown]
# #### Plot your data points.

# %%
plt.scatter(X,Y)

# %% [markdown]
# #### Use your final version of the implemented Batch GD algorithm for single variable to find the best line filt of the given data.
# #### Coose the suitable number of iterations, learning rate, and stop criteria.
# #### Calculate r2 score. Shouldn't below 0.9
# #### Plot the required curves (loss-epochs, loss-theta0, loss-theta1, all fitted lines per epoch (single graph) , best fit line)

# %%
#Batch GD
H=[]
epochs=800
losses=[]
iterations=[]
th0=[]
th1=[]

for i in range(epochs):
    hyp=theta_0+theta_1*X
    c=sum(((hyp)-Y)**2)
    cost=(1/(2*len(X)))*c
    grad_1=(1/m)*sum(theta_0+theta_1*X-Y)
    grad_2=(1/m)*sum((theta_0+theta_1*X-Y)*X)
    th0.append(theta_0)
    th1.append(theta_1)
    theta_0=theta_0-(alpha*grad_1)
    theta_1=theta_1-(alpha*grad_2)
    losses.append(cost)
    iterations.append(i)
    
print("MSE is = ",cost)
print(theta_0)
print(theta_1)
# Out:
# MSE is =  [0.00015016]
# [1.96594199]
# [-0.99746663]

# %%
plt.plot(X,hyp,color="r")
plt.scatter(X,Y)

# %%
plt.plot(iterations,losses)
plt.title('Loss-Epoch relation')
plt.xlabel('Iterations')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')

# %%
plt.plot(th0,losses)
plt.title('theta_0 loss')
plt.xlabel('theta_0')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')

# %%
plt.plot(th1,losses)
plt.title('theta_1 loss')
plt.xlabel('theta_1')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y,hyp)
# Out:
# 0.9994756797264381

# %% [markdown]
# ### Update your Batch GD for one variable  implementation to be Momentum-Based GD and check your results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### γ takes values between 0 and 1.
# ![image.png](attachment:image.png)

# %%
H=[]
epochs=300
alpha=0.001
gamma=0.9
losses=[]
iterations=[]
th0=[]
th1=[]
vt1=0
vt2=0

for i in range(epochs):
    hyp=theta_0+theta_1*X
    c=sum(((hyp)-Y)**2)
    cost=(1/(2*len(X)))*c
    grad_1=(1/m)*sum(theta_0+theta_1*X-Y)
    grad_2=(1/m)*sum((theta_0+theta_1*X-Y)*X)
    th0.append(theta_0)
    th1.append(theta_1)
    vt1=gamma*vt1+(alpha*grad_1)
    vt2=gamma*vt2+(alpha*grad_2)
    theta_0=theta_0-vt1
    theta_1=theta_1-vt2
    losses.append(cost)
    iterations.append(i)
    
print("MSE is = ",cost)
print(theta_0)
print(theta_1)
# Out:
# MSE is =  [0.02598624]
# [1.55198658]
# [-0.96667502]

# %%
plt.plot(X,hyp,color="r")
plt.scatter(X,Y)

# %%
plt.plot(iterations,losses)
plt.title('Loss-Epoch relation')
plt.xlabel('Iterations')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')

# %%
plt.plot(th0,losses)
plt.title('theta_0 loss')
plt.xlabel('theta_0')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')

# %%
plt.plot(th1,losses)
plt.title('theta_1 loss')
plt.xlabel('theta_1')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')

# %%
#trying very small value for gamma
H=[]
epochs=300
alpha=0.001
gamma=0.3
losses=[]
iterations=[]
th0=[]
th1=[]
vt1=0
vt2=0

for i in range(epochs):
    hyp=theta_0+theta_1*X
    c=sum(((hyp)-Y)**2)
    cost=(1/(2*len(X)))*c
    grad_1=(1/m)*sum(theta_0+theta_1*X-Y)
    grad_2=(1/m)*sum((theta_0+theta_1*X-Y)*X)
    th0.append(theta_0)
    th1.append(theta_1)
    vt1=gamma*vt1+(alpha*grad_1)
    vt2=gamma*vt2+(alpha*grad_2)
    theta_0=theta_0-vt1
    theta_1=theta_1-vt2
    losses.append(cost)
    iterations.append(i)
    
print("MSE is = ",cost)
print(theta_0)
print(theta_1)
# Out:
# MSE is =  [0.44048436]
# [0.15129976]
# [-0.86248649]

# %%
plt.plot(X,hyp,color="r")
plt.scatter(X,Y)

# %%
plt.plot(iterations,losses)
plt.title('Loss-Epoch relation')
plt.xlabel('Iterations')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')

# %%
plt.plot(th0,losses)
plt.title('theta_0 loss')
plt.xlabel('theta_0')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')

# %%
plt.plot(th1,losses)
plt.title('theta_1 loss')
plt.xlabel('theta_1')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')

# %% [markdown]
# ### Update your Batch GD for one variable  implementation to be NAG and check your results

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
H=[]
epochs=300
alpha=0.001
gamma=0.9
losses=[]
iterations=[]
th0=[]
th1=[]
vt1=0
vt2=0

for i in range(epochs):
    hyp=theta_0+theta_1*X
    c=sum(((hyp)-Y)**2)
    cost=(1/(2*len(X)))*c
    
    th0.append(theta_0)
    th1.append(theta_1)
    
    theta_temp_0=theta_0-(gamma*vt1)
    theta_temp_1=theta_1-(gamma*vt2)
        
    grad_temp_0=(1/m)*sum(theta_temp_0+theta_temp_1*X-Y)
    grad_temp_1=(1/m)*sum((theta_temp_0+theta_temp_1*X-Y)*X)
    
    
    theta_0=theta_temp_0-(alpha*grad_temp_0)
    vt1=(gamma*vt1)+(alpha*grad_temp_0)
    
    theta_1=theta_temp_1-(alpha*grad_temp_1)
    vt2=(gamma*vt2)+(alpha*grad_temp_1)
    
    losses.append(cost)
    iterations.append(i)
    
print("MSE is = ",cost)
print(theta_0)
print(theta_1)
# Out:
# MSE is =  [0.00099785]
# [1.91220811]
# [-0.9934697]

# %%
plt.plot(X,hyp,color="r")
plt.scatter(X,Y)

# %%
plt.plot(iterations,losses)
plt.title('Loss-Epoch relation')
plt.xlabel('Iterations')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')

# %%
plt.plot(th0,losses)
plt.title('theta_0 loss')
plt.xlabel('theta_0')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')

# %%
plt.plot(th1,losses)
plt.title('theta_1 loss')
plt.xlabel('theta_1')
plt.ylabel('Costs')
# Out:
# Text(0, 0.5, 'Costs')
